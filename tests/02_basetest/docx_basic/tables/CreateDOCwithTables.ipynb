# %% [markdown]
# ## Test tables only
#
# in order to run the following code you should:
# - have package python-docx and Scriptum
# - have some pictures and data ready

# %%
import os, sys, ipytest
from pathlib import Path
ipytest.autoconfig()

# %%
REPORT_DIR = Path(os.getcwd())
#print(os.getcwd(),REPORT_DIR)

TEST_ROOT = REPORT_DIR.parent.parent.parent
if str(TEST_ROOT) not in sys.path:
    sys.path.append(str(TEST_ROOT))

from baseTestRoot import *

import Scriptum # type: ignore
mydoc = None

# %%
def base_setup(tmp_path):

    setupTestEnvironment(tmp_path, DATA_SOURCE, REPORT_DIR, 
                         include_patterns = [
                            "*.rdf",
                            "template_table.docx",
                         ])
    os.chdir(tmp_path)
    print(tmp_path)

# %%
# %%ipytest -vvv -s
# def test_me(tmp_path):
#     global mydoc
#     base_setup(tmp_path)
#
#     rdf = Scriptum.ReportDataFile('word_tables.rdf')
#     if rdf.errors:
#         # assemble collected errors if any
#         print('\n'.join(rdf.errors))
#     #rdf.inspect()
#     #rdf.showFiles()
#
#     mydoc = Scriptum.ManagedDocx('template_table.docx')
#     print(mydoc.errors, mydoc.warnings)
#
#     mydoc.typesetting(rdf,addcopy=True, directfill=True, globalfill=True, cleanup=True, removetemplate=True, cleardust=True, setproperties=True)
#
#     mydoc.save('result_word.docx')#, finish=True, createpdf=True)
#
#     print(tmp_path)
# Out:
# ======================================= test session starts =======================================
# platform win32 -- Python 3.13.1, pytest-8.4.2, pluggy-1.6.0 -- c:\Programs\Python313\python.exe
# cachedir: .pytest_cache
# rootdir: e:\users\tel\Python\site-packages\Scriptum
# configfile: pyproject.toml
# collecting ... collected 1 item
#
# t_9229824f203f4e878b8666478ef53cae.py::test_me <- C:\Users\tel\AppData\Local\Temp\ipykernel_4524\2258018842.py
# TEST runs in C:\Users\tel\AppData\Local\Temp\pytest-of-TEL\pytest-31\test_me0
# C:\Users\tel\AppData\Local\Temp\pytest-of-TEL\pytest-31\test_me0
# PATH C:\Users\tel\AppData\Local\Temp\pytest-of-TEL\pytest-31\test_me0 data
# [] []
# check consistency
#    add and copy new paragraphs and more ...
# WARNING: No such template in document: ['section:template', 'table:orange']
#    fill the content...
# WARNING: No exact match: ['section:title', 'table:orange_c002']
#    fill the global content...
#    clean up...
#    remove template section...
# INFO: Correcting header to be linked to previous to save previous header
# INFO: Correcting footer to be linked to previous to save previous footer
#    clearing all the dust...
#    set properties...
# done
# C:\Users\tel\AppData\Local\Temp\pytest-of-TEL\pytest-31\test_me0
# PASSED
#
# ======================================== 1 passed in 0.12s ========================================

# %%
props =  ['author','category', 'comments', 'created', 
          'identifier', 'keywords', 'language', 'last_modified_by', 'modified',
          'last_printed', 'revision', 'subject', 'title', 'version' ] 
# skipped some
for prop in props:
    print("prop %r, value %r"%(prop,getattr(mydoc.document.core_properties,prop)))
# Out:
# prop 'author', value 'Scriptum 1.2.0'
# prop 'category', value ''
# prop 'comments', value ''
# prop 'created', value datetime.datetime(2025, 10, 25, 12, 25, tzinfo=datetime.timezone.utc)
# prop 'identifier', value ''
# prop 'keywords', value ''
# prop 'language', value ''
# prop 'last_modified_by', value 'EMMEL Thomas'
# prop 'modified', value datetime.datetime(2025, 11, 9, 16, 46, tzinfo=datetime.timezone.utc)
# prop 'last_printed', value None
# prop 'revision', value 17
# prop 'subject', value ''
# prop 'title', value 'Autoreport'
# prop 'version', value ''

# %%
for s in mydoc.sections:
    s.inspect()
# Out:
# STRUCTURE (start): section:title
#   path: ['section:title']
#   parent: None
#   me: <Scriptum._docx.section.section.Section object at 0x000002712B7AD940>
#   will iterate as:
#   tagged element: <section:title> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B7BC130>' --> b''...
#   simple element: None element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B74EF70>' --> b''...
#   tagged element: <date:creation/> element of type table: '<docx.table.Table object at 0x000002712B76CE90>': cols=2 rows=1
#   simple element: None element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B6F9FD0>' --> b''...
#   simple element: None element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B6FAC90>' --> b'Revisions (of docume'...
#   tagged element: <date:creation/> element of type table: '<docx.table.Table object at 0x000002712B7A1490>': cols=3 rows=5
#   tagged element: <author/> element of type table: '<docx.table.Table object at 0x000002712B7A1490>': cols=3 rows=5
#   simple element: None element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B77D860>' --> b''...
#    TABLE (start): table:inline
#      path: ['section:title', 'table:inline']
#      parent: <Scriptum._docx.section.section.Section object at 0x000002712B7AD940>
#      me: <Scriptum._docx.tables.element.DocTableBlockElement object at 0x000002712B7AE510>
#      will iterate as:
#      tagged element: <table:inline> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B77D910>' --> b"non existing file 'd"...
#      simple element: None element of type table: '<docx.table.Table object at 0x000002712B67BDF0>': cols=3 rows=2
#      tagged element: <description/> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B763C50>' --> b'Table 1: '...
#      tagged element: </table:inline> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B763A70>' --> b''...
#    TABLE (end): inline
#    TABLE (start): table:orange
#      path: ['section:title', 'table:orange']
#      parent: <Scriptum._docx.section.section.Section object at 0x000002712B7AD940>
#      me: <Scriptum._docx.tables.element.DocTableBlockElement object at 0x000002712B796850>
#      will iterate as:
#      tagged element: <table:orange template> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B61B380>' --> b''...
#      simple element: None element of type table: '<docx.table.Table object at 0x000002712B67BCE0>': cols=3 rows=8
#      tagged element: <description/> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B7A6CD0>' --> b'Table 1: Income by c'...
#      tagged element: </table:orange> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B7A6D50>' --> b''...
#    TABLE (end): orange
#   tagged element: <marker:content/> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B7A84B0>' --> b''...
#   tagged element: <report:ID/> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B74B290>' --> b'Company X \xe2\x80\x93 Report'...
#   tagged element: <report:ID/> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B74B350>' --> b'Foot sec title ID 00'...
#   tagged element: </section:title> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B7A8600>' --> b''...
#    TABLE (start): table:generic
#      path: ['section:title', 'table:generic']
#      parent: <Scriptum._docx.section.section.Section object at 0x000002712B7AD940>
#      me: <Scriptum._docx.tables.element.DocTableBlockElement object at 0x000002712B7A17F0>
#      will iterate as:
#      tagged element: <table:generic> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B74BCB0>' --> b"non existing file 'd"...
#      simple element: None element of type table: '<docx.table.Table object at 0x000002712B74FA00>': cols=2 rows=2
#      tagged element: <description/> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B74B5F0>' --> b'Table 4: '...
#      tagged element: </table:generic> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B74B770>' --> b''...
#    TABLE (end): generic
#   anchor: element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B7A8600>' --> b''... <docx.text.paragraph.Paragraph object at 0x000002712B7A8600>
# STRUCTURE (end): title
# STRUCTURE (start): section:template
#   path: ['section:template']
#   parent: None
#   me: <Scriptum._docx.section.section.Section object at 0x000002712B796AD0>
#   will iterate as:
#   tagged element: <section:template> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B74BC50>' --> b''...
#    TABLE (start): table:narrow
#      path: ['section:template', 'table:narrow']
#      parent: <Scriptum._docx.section.section.Section object at 0x000002712B796AD0>
#      me: <Scriptum._docx.tables.element.DocTableBlockElement object at 0x000002712B796C10>
#      will iterate as:
#      tagged element: <table:narrow> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B74BD10>' --> b''...
#      simple element: None element of type table: '<docx.table.Table object at 0x000002712B6C33E0>': cols=2 rows=2
#      tagged element: <description/> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B74BD70>' --> b'Table 2: '...
#      tagged element: </table:narrow> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B74BDD0>' --> b''...
#    TABLE (end): narrow
#    TABLE (start): table:left
#      path: ['section:template', 'table:left']
#      parent: <Scriptum._docx.section.section.Section object at 0x000002712B796AD0>
#      me: <Scriptum._docx.tables.element.DocTableBlockElement object at 0x000002712B76E060>
#      will iterate as:
#      tagged element: <table:left> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B74BE30>' --> b''...
#      simple element: None element of type table: '<docx.table.Table object at 0x000002712B7BC910>': cols=2 rows=2
#      tagged element: <description/> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B74BE90>' --> b'Table 3: '...
#      tagged element: </table:left> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B74BEF0>' --> b''...
#    TABLE (end): left
#   simple element: None element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B74BF50>' --> b'The next table can b'...
#    TABLE (start): table:generic
#      path: ['section:template', 'table:generic']
#      parent: <Scriptum._docx.section.section.Section object at 0x000002712B796AD0>
#      me: <Scriptum._docx.tables.element.DocTableBlockElement object at 0x000002712B76E190>
#      will iterate as:
#      tagged element: <table:generic> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B74BFB0>' --> b''...
#      simple element: None element of type table: '<docx.table.Table object at 0x000002712B7BC670>': cols=2 rows=2
#      tagged element: <description/> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B7CC050>' --> b'Table 4: '...
#      tagged element: </table:generic> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B7CC0B0>' --> b''...
#    TABLE (end): generic
#   tagged element: </section:template> element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B7CC110>' --> b''...
#   anchor: element of type paragraph : '<docx.text.paragraph.Paragraph object at 0x000002712B7CC110>' --> b''... <docx.text.paragraph.Paragraph object at 0x000002712B7CC110>
# STRUCTURE (end): template

# %%
for elem in mydoc.document.sections[0].iter_inner_content():
    print(elem)
# Out:
# <docx.text.paragraph.Paragraph object at 0x000002712B748110>
# <docx.table.Table object at 0x00000271256C8EC0>
# <docx.text.paragraph.Paragraph object at 0x000002712B748110>
# <docx.text.paragraph.Paragraph object at 0x000002712B74BAD0>
# <docx.table.Table object at 0x000002712B763430>
# <docx.text.paragraph.Paragraph object at 0x000002712B74BAD0>
# <docx.text.paragraph.Paragraph object at 0x000002712B748110>
# <docx.table.Table object at 0x000002712B763430>
# <docx.text.paragraph.Paragraph object at 0x000002712B748110>
# <docx.table.Table object at 0x000002712A8A0F80>
# <docx.text.paragraph.Paragraph object at 0x000002712B748110>
# <docx.text.paragraph.Paragraph object at 0x000002712B74BAD0>
# <docx.table.Table object at 0x000002712B78DED0>
# <docx.text.paragraph.Paragraph object at 0x000002712B74BAD0>
# <docx.text.paragraph.Paragraph object at 0x000002712B748110>
