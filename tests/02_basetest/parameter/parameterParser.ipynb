# %% [markdown]
# # a parameter parser for simple name:value files

# %%
import ipytest
ipytest.autoconfig()

# %%
# %%ipytest -vvv -s
# from test_parameter import *
# Out:
# ======================================= test session starts =======================================
# platform win32 -- Python 3.13.1, pytest-8.4.2, pluggy-1.6.0 -- c:\Programs\Python313\python.exe
# cachedir: .pytest_cache
# rootdir: e:\users\tel\Python\site-packages\Scriptum\tests\02_basetest\parameter
# collecting ... collected 1 item
#
# t_53a76d8f49754bb3bf564c45bfb8d030.py::test_parameter_case1 <- test_parameter.py    section.position = parfile 'basic.nv' exists: True (parameterfile) - parameter to look for: 'Modified'
# PASSED
#
# ======================================== 1 passed in 0.01s ========================================

# %%
stop here
# Out:
#   Cell In[3], line 1
#     stop here
#          ^
# SyntaxError: invalid syntax

# %%
from tempfile import TemporaryDirectory
import os

tempdir = TemporaryDirectory()
tmp_path = Path(tempdir.name)
os.chdir(tmp_path)

rdf_path = write(
        tmp_path, "namevalue.rdf",
        """*version=100
            section
            .position=parfile:basic.nv:Modified
        """,
    )

nv_path = write(
        tmp_path, 'basic.nv',
        """Title:WhatEver-F1
CreatedFrom:Variant B
Revision: 0815
FileIsOpen:0
Modified:1566996265000
this is a long text:'abc
def
geh
ijk'
"""
    )

rdf = ReportDataFile(str(rdf_path), _root=[])

# %%
rdf.inspect()
# Out:
# [{'number': 3,
#   'path': ['section', 'position'],
#   'value': parfile 'basic.nv' exists: True (parameterfile) - parameter to look for: 'Modified',
#   'address': ['section', 'position_c003'],
#   'target': 'position'}]

# %%
task = rdf.tasks[0]
task.value.load()

# %%
task.value.content
# Out:
# 'Wed Aug 28 14:44:25 2019'
