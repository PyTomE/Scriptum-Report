# %% [markdown]
# # Setup tests

# %%
import ipytest

ipytest.autoconfig()

# %%
# %%ipytest -vvv -s
# from test_length_value import *
# from test_numbers_and_more import *
# from test_date_value import *
# from test_table_value import *
# from test_text_value import *
# from test_namevalues_value import *
# from test_image_value import *
# from test_color_value import *
# Out:
# ======================================= test session starts =======================================
# platform win32 -- Python 3.13.1, pytest-8.4.2, pluggy-1.6.0 -- c:\Programs\Python313\python.exe
# cachedir: .pytest_cache
# rootdir: e:\users\tel\Python\site-packages\Scriptum\tests\02_basetest\values
# collecting ... collected 29 items
#
# t_6889d29362e841fba253602e1a7407f5.py::test_length_units <- test_length_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_counter_formats <- test_numbers_and_more.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_number_formats <- test_numbers_and_more.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_date_time_strings <- test_date_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_tables <- test_table_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_text_value_temperatures_existing_file <- test_text_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_text_value_missing_file_returns_placeholder <- test_text_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_text_value_embedded_literal <- test_text_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_namevalue_parses_timestamp_fields <- test_namevalues_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_namevalue_missing_file_falls_back_to_message <- test_namevalues_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_strtotime_edge_cases[1566995546-expected0] <- test_namevalues_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_strtotime_edge_cases[1566995546000-expected1] <- test_namevalues_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_strtotime_edge_cases[123456789-expected2] <- test_namevalues_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_strtotime_edge_cases[12345-None] <- test_namevalues_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_strtotime_edge_cases[-None] <- test_namevalues_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_image_value_temperatures_dimensions <- test_image_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_image_value_missing_file_returns_placeholder <- test_image_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_image_value_propagates_open_errors <- test_image_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_color_value_normalization[red-FF0000-expected_rgb0] <- test_color_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_color_value_normalization[LightGray-D3D3D3-expected_rgb1] <- test_color_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_color_value_normalization[aliceblue-F0F8FF-expected_rgb2] <- test_color_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_color_value_normalization[RoyalBlue-4169E1-expected_rgb3] <- test_color_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_color_value_normalization[#00ff00-00FF00-expected_rgb4] <- test_color_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_color_value_normalization[0000ff-0000FF-expected_rgb5] <- test_color_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_color_value_invalid_input[] <- test_color_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_color_value_invalid_input[   ] <- test_color_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_color_value_invalid_input[not-a-color] <- test_color_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_color_value_invalid_input[#12345] <- test_color_value.py PASSED
# t_6889d29362e841fba253602e1a7407f5.py::test_color_value_invalid_input[#1234567] <- test_color_value.py PASSED
#
# ======================================= 29 passed in 6.75s ========================================
