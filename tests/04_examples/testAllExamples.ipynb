# %% [markdown]
# # a test on all examples

# %%
import ipytest
import os
ipytest.autoconfig()
curdir = os.getcwd()

# %%
# %%ipytest -vvv -s
# os.chdir('essay')
# from test_essay_docx_generation import *
# os.chdir(curdir)
# Out:
# ======================================= test session starts =======================================
# platform win32 -- Python 3.13.1, pytest-8.4.2, pluggy-1.6.0 -- c:\Programs\Python313\python.exe
# cachedir: .pytest_cache
# rootdir: e:\users\tel\Python\site-packages\Scriptum\tests\04_examples
# collecting ... collected 1 item
#
# t_28580eea9f1948e589cb7b826bcbcc7c.py::test_essay_document_is_created <- essay\test_essay_docx_generation.py
# Working in C:\Users\tel\AppData\Local\Temp\pytest-of-TEL\pytest-6\test_essay_document_is_created0
# check consistency
#    add and copy new paragraphs and more ...
#    fill the content...
#    fill the global content...
#    clean up...
#    remove template section...
#    clearing all the dust...
#    set properties...
# done
# PASSED
#
# ======================================== 1 passed in 5.14s ========================================
